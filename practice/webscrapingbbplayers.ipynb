# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import pandas as pd

# %%
# Create the web driver to access the page information

cService = webdriver.ChromeService(executable_path="C:/Users/saahi/Downloads/CS/chromedriver-win64/chromedriver-win64/chromedriver.exe")

driver = webdriver.Chrome(service=cService)

# %%
# Create the master dataframe

df = pd.DataFrame(columns=['Player','Salary','Year'])

# %%
# Loop through each page by year
for yr in range(1990,2025):
    page_num = str(yr) + '-' + str(yr+1) +'/'
    url = 'https://hoopshype.com/salaries/players/' + page_num
    driver.get(url)
   
    players = driver.find_elements(By.XPATH, '//td[@class="name"]')
    salaries = driver.find_elements(By.XPATH, '//td[@class="hh-salaries-sorted"]')
   
    # Append players into a list
    players_list = []
    for p in range(len(players)):
        players_list.append(players[p].text)
   
    # Append salaries into a list
    salaries_list = []
    for s in range(len(salaries)):
        salaries_list.append(salaries[s].text)
   
    p = int(len(players_list)/2)+1  # marks position of first player in players_list -- first half of list is empty
    s = int(len(salaries_list)/2)-1  # marks position of last salary of salaries_list -- second half of list is empty


    data_tuples = list(zip(players_list[p:],salaries_list[1:s])) # list of each players name and salary paired together
    temp_df = pd.DataFrame(data_tuples, columns=['Player','Salary']) # creates dataframe of each tuple in list
    temp_df['Year'] = yr + 1 # adds season ending year to each dataframe

    print(temp_df)

    # Add the temporary dataframes to the master dataframe
    df = pd.concat([df, temp_df], ignore_index=True)
   
driver.close()
# Out:
#                 Player      Salary  Year
# 0       Dave Greenwood  $4,250,000  1991
# 1       Duane Causwell  $3,785,000  1991
# 2       Sedale Threatt  $3,175,000  1991
# 3        Jay Humphries  $2,900,000  1991
# 4        Dave Jamerson  $2,850,000  1991
# ..                 ...         ...   ...
# 169         Tony Brown    $675,000  1991
# 170     Alan Bannister    $675,000  1991
# 171      Avery Johnson    $675,000  1991
# 172         Mario Elie    $667,000  1991
# 173  Anthony Frederick    $658,000  1991
#
# [174 rows x 3 columns]
#                  Player      Salary  Year
# 0         Nick Anderson  $7,070,000  1992
# 1        Olden Polynice  $3,786,000  1992
# 2      Victor Alexander  $3,500,000  1992
# 3         Jerrod Mustaf  $3,340,000  1992
# 4         Nate McMillan  $3,250,000  1992
# ..                  ...         ...   ...
# 185        Gary Leonard    $775,000  1992
# 186        Rory Sparrow    $763,000  1992
# 187         Paul Graham    $760,000  1992
# 188  Kennard Winchester    $760,000  1992
# 189        Chuck Nevitt    $760,000  1992
#
# [190 rows x 3 columns]
#                     Player      Salary  Year
# 0            Willie Burton  $5,720,000  1993
# 1                 Ed Nealy  $4,000,000  1993
# 2    Clarence Weatherspoon  $3,786,000  1993
# 3            Nick Anderson  $3,633,000  1993
# 4            John Williams  $3,513,000  1993
# ..                     ...         ...   ...
# 194            Matt Othick    $865,000  1993
# 195           Corey Gaines    $865,000  1993
# 196             Reggie Fox    $850,000  1993
# 197          Ricky Blanton    $850,000  1993
# 198           Tito Horford    $850,000  1993
#
# [199 rows x 3 columns]
#                  Player      Salary  Year
# 0          Bryant Stith  $5,740,000  1994
# 1          Kevin Gamble  $5,050,000  1994
# 2           Tyrone Hill  $4,886,000  1994
# 3         Jerrod Mustaf  $4,133,000  1994
# 4          Terry Dehere  $4,000,000  1994
# ..                  ...         ...   ...
# 186       Ennis Whatley  $1,120,000  1994
# 187   Eddie Lee Wilkins  $1,120,000  1994
# 188         Roy Tarpley  $1,112,000  1994
# 189  Darren Morningstar  $1,110,000  1994
# 190         Tracy Moore  $1,100,000  1994
#
# [191 rows x 3 columns]
#               Player       Salary  Year
# 0    Jayson Williams  $14,660,000  1995
# 1     Pervis Ellison   $7,300,000  1995
# 2         Joe Dumars   $7,250,000  1995
# 3       Scott Haskin   $6,472,600  1995
# 4          Vin Baker   $5,000,000  1995
# ..               ...          ...   ...
# 202      Keith Tower   $1,160,000  1995
# 203      Rod Higgins   $1,150,000  1995
# 204     Joe Courtney   $1,137,500  1995
# 205     Kevin Rankin   $1,125,000  1995
# 206       Todd Mundt   $1,120,000  1995
#
# [207 rows x 3 columns]
#                Player       Salary  Year
# 0     Eric Piatkowski  $18,724,000  1996
# 1         Ed O'Bannon   $9,810,000  1996
# 2         Greg Graham   $7,700,000  1996
# 3        Hubert Davis   $7,000,000  1996
# 4       Johnny Newman   $6,881,000  1996
# ..                ...          ...   ...
# 219       Kurt Rambis   $1,200,000  1996
# 220     Kareem Townes   $1,200,000  1996
# 221       Gerard King   $1,200,000  1996
# 222  Grady Livingston   $1,184,000  1996
# 223        Nate Higgs   $1,177,000  1996
#
# [224 rows x 3 columns]
#              Player       Salary  Year
# 0    James Robinson  $30,140,000  1997
# 1      Corie Blount  $14,857,000  1997
# 2       Sam Cassell  $11,250,000  1997
# 3       Chris Mills  $10,714,000  1997
# 4     Scott Burrell  $10,212,000  1997
# ..              ...          ...   ...
# 201   Lloyd Daniels   $1,293,000  1997
# 202  Stephen Howard   $1,280,000  1997
# 203     Henry James   $1,246,000  1997
# 204  Aaron Williams   $1,238,000  1997
# 205  Robert Werdann   $1,235,000  1997
#
# [206 rows x 3 columns]
#              Player       Salary  Year
# 0     Johnny Newman  $33,140,000  1998
# 1      Lee Mayberry  $20,500,000  1998
# 2       Todd Fuller  $14,285,714  1998
# 3     Danny Fortson  $12,857,143  1998
# 4    Cherokee Parks  $12,397,440  1998
# ..              ...          ...   ...
# 215    Scott Brooks   $1,402,000  1998
# 216    Jerome Allen   $1,400,000  1998
# 217   Patrick Savoy   $1,398,960  1998
# 218       Ben Davis   $1,359,360  1998
# 219  Amal McCaskill   $1,333,800  1998
#
# [220 rows x 3 columns]
#              Player       Salary  Year
# 0     Samaki Walker  $18,500,000  1999
# 1    Robert Traylor  $15,000,000  1999
# 2     Tracy McGrady  $14,841,000  1999
# 3       Bill Curley  $14,000,000  1999
# 4      Lee Mayberry  $13,130,000  1999
# ..              ...          ...   ...
# 206       Cory Carr   $1,680,000  1999
# 207   Charles Jones   $1,670,000  1999
# 208    Kornel David   $1,657,000  1999
# 209     Brad Miller   $1,650,000  1999
# 210  Marlon Garnett   $1,650,000  1999
#
# [211 rows x 3 columns]
#               Player       Salary  Year
# 0    Austin Croshere  $17,142,858  2000
# 1        Paul Pierce  $16,806,300  2000
# 2    Dickey Simpkins  $15,004,800  2000
# 3        Jason Terry  $15,000,000  2000
# 4     Derek Anderson  $15,000,000  2000
# ..               ...          ...   ...
# 251      John Morton   $1,610,000  2000
# 252  Jonathan Kerner   $1,603,861  2000
# 253       Andy Panko   $1,594,920  2000
# 254   Steve Goodrich   $1,583,040  2000
# 255    Trevor Winter   $1,560,000  2000
#
# [256 rows x 3 columns]
#              Player       Salary  Year
# 0     Carlos Rogers  $19,610,000  2001
# 1    Terry Cummings  $19,285,715  2001
# 2     Michael Curry  $16,880,000  2001
# 3      John Wallace  $16,875,000  2001
# 4    George McCloud  $16,700,000  2001
# ..              ...          ...   ...
# 221    Milt Palacio   $2,200,000  2001
# 222     Mark Blount   $2,200,000  2001
# 223   Hanno Mottola   $2,200,000  2001
# 224    Mark Karcher   $2,200,000  2001
# 225  Jamal Robinson   $2,200,000  2001
#
# [226 rows x 3 columns]
#                Player       Salary  Year
# 0    Wally Szczerbiak  $22,400,000  2002
# 1          Malik Rose  $21,428,572  2002
# 2     Vinny Del Negro  $18,754,800  2002
# 3     DerMarr Johnson  $18,750,000  2002
# 4       Shane Battier  $18,083,564  2002
# ..                ...          ...   ...
# 218          Sam Mack   $2,400,000  2002
# 219      Isaiah Rider   $2,400,000  2002
# 220      Charlie Bell   $2,400,000  2002
# 221     Tang Hamilton   $2,400,000  2002
# 222       Joe Crispin   $2,400,000  2002
#
# [223 rows x 3 columns]
#              Player       Salary  Year
# 0      Shawn Marion  $25,200,000  2003
# 1        Chris Mihm  $23,571,429  2003
# 2     Eddie Griffin  $20,629,800  2003
# 3       Jason Terry  $20,625,000  2003
# 4    Cory Alexander  $19,727,524  2003
# ..              ...          ...   ...
# 219  Antonio Harvey   $2,400,000  2003
# 220      Mike Wilks   $2,400,000  2003
# 221    Rafer Alston   $2,400,000  2003
# 222     Devin Brown   $2,392,500  2003
# 223      Guy Rucker   $2,368,200  2003
#
# [224 rows x 3 columns]
#                Player       Salary  Year
# 0             TJ Ford  $28,000,000  2004
# 1    Hidayet Turkoglu  $24,749,999  2004
# 2        Rodney White  $17,714,291  2004
# 3         Marko Jaric  $17,000,000  2004
# 4    Amare Stoudemire  $15,937,500  2004
# ..                ...          ...   ...
# 220     Slavko Vranes   $2,185,920  2004
# 221      Sean Lampley   $2,168,193  2004
# 222        Shane Heal   $2,120,000  2004
# 223    Torraye Braggs   $2,118,840  2004
# 224   Britton Johnsen   $2,102,840  2004
#
# [225 rows x 3 columns]
#                  Player       Salary  Year
# 0               TJ Ford  $27,696,430  2005
# 1           Marko Jaric  $19,485,719  2005
# 2         Rafael Araujo  $17,531,250  2005
# 3      Amare Stoudemire  $17,531,250  2005
# 4         Mike Sweetney  $16,000,000  2005
# ..                  ...          ...   ...
# 228         Yuta Tabuse   $2,273,400  2005
# 229        Awvee Storey   $2,266,794  2005
# 230  Courtney Alexander   $2,260,280  2005
# 231    Tremaine Fowlkes   $2,231,808  2005
# 232       Geno Carlisle   $2,210,880  2005
#
# [233 rows x 3 columns]
#               Player       Salary  Year
# 0       Caron Butler  $20,000,000  2006
# 1          Luol Deng  $19,125,000  2006
# 2     Jared Jeffries  $19,125,000  2006
# 3    Anthony Johnson  $18,612,500  2006
# 4         Melvin Ely  $18,000,000  2006
# ..               ...          ...   ...
# 233       Matt Walsh   $2,500,000  2006
# 234   Ben Handlogten   $2,500,000  2006
# 235       John Lucas   $2,500,000  2006
# 236   Kaniel Dickens   $2,500,000  2006
# 237   Melvin Sanders   $2,500,000  2006
#
# [238 rows x 3 columns]
#                  Player       Salary  Year
# 0         Jackie Butler  $21,000,000  2007
# 1          Scot Pollard  $20,000,000  2007
# 2    Othella Harrington  $19,030,999  2007
# 3       Zarko Cabarkapa  $18,261,024  2007
# 4             Ike Diogu  $18,084,000  2007
# ..                  ...          ...   ...
# 241     Luke Schenscher   $2,333,334  2007
# 242    Kevin Pittsnogle   $2,325,000  2007
# 243         Will Conroy   $2,250,000  2007
# 244      Casey Jacobsen   $2,242,290  2007
# 245           Von Wafer   $2,210,000  2007
#
# [246 rows x 3 columns]
#                 Player       Salary  Year
# 0           Randy Foye  $23,750,000  2008
# 1         Robert Swift  $21,696,750  2008
# 2    Sebastian Telfair  $20,000,000  2008
# 3           Juan Dixon  $19,728,000  2008
# 4         Corey Brewer  $19,728,000  2008
# ..                 ...          ...   ...
# 228     Darryl Watkins   $2,804,889  2008
# 229     Thomas Gardner   $2,777,760  2008
# 230       Orien Greene   $2,762,500  2008
# 231     Guillermo Diaz   $2,750,000  2008
# 232     Stephane Lasme   $2,715,000  2008
#
# [233 rows x 3 columns]
#                    Player       Salary  Year
# 0        Danilo Gallinari  $24,751,934  2009
# 1    Didier Ilunga-Mbenga  $21,372,000  2009
# 2              Randy Foye  $21,372,000  2009
# 3            Andrew Bynum  $21,262,500  2009
# 4          Andray Blatche  $21,000,000  2009
# ..                    ...          ...   ...
# 223          Blake Ahearn   $3,093,333  2009
# 224        Linton Johnson   $3,084,240  2009
# 225           Andre Brown   $3,000,000  2009
# 226      Demetris Nichols   $2,987,000  2009
# 227         Desmon Farmer   $2,986,080  2009
#
# [228 rows x 3 columns]
#                   Player       Salary  Year
# 0            Eric Gordon  $23,239,562  2010
# 1       Hilton Armstrong  $23,034,375  2010
# 2        Thabo Sefolosha  $23,016,000  2010
# 3    Aleksandar Pavlovic  $22,183,220  2010
# 4          Dorell Wright  $20,000,000  2010
# ..                   ...          ...   ...
# 221           Paul Davis   $3,000,000  2010
# 222        Desmond Mason   $3,000,000  2010
# 223          Mike Harris   $2,969,280  2010
# 224       Cedric Jackson   $2,916,120  2010
# 225          Will Conroy   $2,862,000  2010
#
# [226 rows x 3 columns]
#               Player       Salary  Year
# 0    Al-Farouq Aminu  $24,806,250  2011
# 1        DJ Augustin  $19,573,711  2011
# 2      Maurice Evans  $18,800,000  2011
# 3     David Andersen  $18,700,000  2011
# 4      Dahntay Jones  $18,300,000  2011
# ..               ...          ...   ...
# 223     Trey Johnson   $2,855,700  2011
# 224     Maurice Ager   $2,814,196  2011
# 225    Bobby Simmons   $2,798,040  2011
# 226     Matt Janning   $2,767,126  2011
# 227    Ronald Dupree   $2,700,000  2011
#
# [228 rows x 3 columns]
#                 Player       Salary  Year
# 0        Kenyon Martin  $25,244,493  2012
# 1      Reggie Williams  $21,300,000  2012
# 2    DeShawn Stevenson  $21,247,044  2012
# 3     Brandon Jennings  $21,164,619  2012
# 4         Ryan Hollins  $21,136,631  2012
# ..                 ...          ...   ...
# 225      Brian Skinner   $2,625,000  2012
# 226          Ike Diogu   $2,588,590  2012
# 227           Ben Uzoh   $2,563,320  2012
# 228       Andre Emmett   $2,541,000  2012
# 229       Garret Siler   $2,532,960  2012
#
# [230 rows x 3 columns]
#                Player       Salary  Year
# 0          Randy Foye  $27,849,000  2013
# 1         Jason Smith  $21,459,805  2013
# 2     Reggie Williams  $20,907,128  2013
# 3        Cole Aldrich  $20,807,922  2013
# 4         Jeff Teague  $19,948,799  2013
# ..                ...          ...   ...
# 240      Damion James   $2,706,940  2013
# 241  Andrew Goudelock   $2,674,851  2013
# 242    Justin Dentmon   $2,575,000  2013
# 243      Josh Akognon   $2,574,120  2013
# 244        Eddy Curry   $2,563,320  2013
#
# [245 rows x 3 columns]
#                   Player       Salary  Year
# 0        Wayne Ellington  $30,453,000  2014
# 1        DeMarre Carroll  $22,721,381  2014
# 2         Andre Drummond  $22,346,536  2014
# 3             Trey Burke  $21,679,893  2014
# 4          Trevor Booker  $21,490,000  2014
# ..                   ...          ...   ...
# 239       James Nunnally   $2,626,473  2014
# 240  Darius Johnson-Odom   $2,612,500  2014
# 241       Mustafa Shakur   $2,585,668  2014
# 242          DJ Stephens   $2,511,432  2014
# 243        Tony Mitchell   $2,500,000  2014
#
# [244 rows x 3 columns]
#                       Player       Salary  Year
# 0             Meyers Leonard  $23,500,000  2015
# 1    Michael Carter-Williams  $23,180,790  2015
# 2             Doug McDermott  $22,458,401  2015
# 3              Nick Collison  $21,896,658  2015
# 4                Jeremy Lamb  $21,436,271  2015
# ..                       ...          ...   ...
# 250              Malcolm Lee   $2,500,000  2015
# 251              Sim Bhullar   $2,439,840  2015
# 252               David Wear   $2,433,333  2015
# 253          Sean Kilpatrick   $2,421,000  2015
# 254             Jarell Eddie   $2,397,840  2015
#
# [255 rows x 3 columns]
#                      Player       Salary  Year
# 0               Noah Vonleh  $25,000,000  2016
# 1              Tyler Zeller  $22,970,500  2016
# 2            Frank Kaminsky  $22,875,000  2016
# 3               CJ McCollum  $22,359,364  2016
# 4             Elfrid Payton  $22,309,344  2016
# ..                      ...          ...   ...
# 243         Elliot Williams   $2,814,000  2016
# 244           Quincy Miller   $2,814,000  2016
# 245              JJ O'Brien   $2,814,000  2016
# 246  Thanasis Antetokounmpo   $2,814,000  2016
# 247           Nate Robinson   $2,700,000  2016
#
# [248 rows x 3 columns]
#                Player       Salary  Year
# 0          Seth Curry  $30,963,450  2017
# 1    Tomas Satoransky  $26,540,100  2017
# 2        Tibor Pleiss  $26,540,100  2017
# 3         Noah Vonleh  $26,540,100  2017
# 4      Frank Kaminsky  $26,540,100  2017
# ..                ...          ...   ...
# 266      Phil Pressey   $2,941,440  2017
# 267  Nikola Jovanovic   $2,898,000  2017
# 268       Tony Wroten   $2,898,000  2017
# 269     Nick Zeisloft   $2,898,000  2017
# 270       Jalen Jones   $2,898,000  2017
#
# [271 rows x 3 columns]
#                   Player       Salary  Year
# 0         Shabazz Napier  $34,682,550  2018
# 1          Rashad Vaughn  $33,285,709  2018
# 2           Clint Capela  $30,769,231  2018
# 3          Nick Collison  $29,727,900  2018
# 4         Raymond Felton  $29,512,900  2018
# ..                   ...          ...   ...
# 286           VJ Beachem   $2,451,224  2018
# 287         Landry Nnoko   $2,442,455  2018
# 288         Andre Ingram   $2,441,400  2018
# 289  Trey McKinney-Jones   $2,422,560  2018
# 290        Aaron Jackson   $2,422,560  2018
#
# [291 rows x 3 columns]
#               Player       Salary  Year
# 0        Dario Saric  $37,457,154  2019
# 1     Taurean Prince  $35,665,000  2019
# 2    Justin Anderson  $35,654,150  2019
# 3       Shelvin Mack  $35,654,150  2019
# 4      Manu Ginobili  $32,700,000  2019
# ..               ...          ...   ...
# 281    Dusty Hannahs   $2,667,600  2019
# 282    Stephan Hicks   $2,659,800  2019
# 283  Michael Frazier   $2,639,313  2019
# 284   Tahjere McCall   $2,615,160  2019
# 285   Mitchell Creek   $2,559,925  2019
#
# [286 rows x 3 columns]
#               Player       Salary  Year
# 0       Luka Samanic  $40,231,758  2020
# 1       John Collins  $38,506,482  2020
# 2      Kevin Huerter  $38,506,482  2020
# 3       Caris LeVert  $38,199,000  2020
# 4      Marko Guduric  $38,199,000  2020
# ..               ...          ...   ...
# 251    Chris Chiozza   $2,905,800  2020
# 252  Jeremiah Martin   $2,875,000  2020
# 253   Tremont Waters   $2,816,760  2020
# 254       Tacko Fall   $2,813,280  2020
# 255    Charlie Brown   $2,764,200  2020
#
# [256 rows x 3 columns]
#                Player       Salary  Year
# 0       Lonnie Walker  $43,006,362  2021
# 1        Ben McLemore  $41,358,814  2021
# 2    Andrew Nicholson  $41,358,814  2021
# 3        Luka Samanic  $41,254,920  2021
# 4          Josh Green  $41,254,920  2021
# ..                ...          ...   ...
# 282        Louis King   $3,051,832  2021
# 283    Cameron Oliver   $3,044,160  2021
# 284      Cam Reynolds   $3,011,499  2021
# 285      Andrew White   $3,000,000  2021
# 286        Tyler Hall   $3,000,000  2021
#
# [287 rows x 3 columns]
#                 Player       Salary  Year
# 0          Otto Porter  $45,780,966  2022
# 1      Leandro Bolmaro  $44,310,840  2022
# 2         Usman Garuba  $44,310,840  2022
# 3    Willy Hernangomez  $44,211,146  2022
# 4        Edmond Sumner  $42,018,900  2022
# ..                 ...          ...   ...
# 320      Malik Ellison   $2,401,537  2022
# 321     Anthony Barber   $2,401,537  2022
# 322       Luca Vildoza   $2,389,641  2022
# 323     Zavier Simpson   $2,389,641  2022
# 324  Mfiondu Kabengele   $2,389,641  2022
#
# [325 rows x 3 columns]
#                 Player       Salary  Year
# 0          Trey Murphy  $48,070,014  2023
# 1    Simone Fontecchio  $47,345,760  2023
# 2       Andre Drummond  $47,080,179  2023
# 3        Derrick Jones  $44,474,988  2023
# 4          Dalen Terry  $44,119,845  2023
# ..                 ...          ...   ...
# 280      Justin Minaya   $3,433,320  2023
# 281       Kobi Simmons   $3,423,750  2023
# 282          Gabe York   $3,395,062  2023
# 283         Ibou Badji   $3,375,360  2023
# 284   Tristan Thompson   $3,359,160  2023
#
# [285 rows x 3 columns]
#                  Player       Salary  Year
# 0           Jae Crowder  $51,915,615  2024
# 1          Derrick Rose  $47,649,433  2024
# 2           Cory Joseph  $47,607,350  2024
# 3        DeAndre Jordan  $47,607,350  2024
# 4        Justin Holiday  $47,607,350  2024
# ..                  ...          ...   ...
# 299          Taze Moore   $3,198,778  2024
# 300      Taevion Kinsey   $3,196,448  2024
# 301  Izaiah Brockington   $3,196,448  2024
# 302      Jalen Crutcher   $3,196,448  2024
# 303         Timmy Allen   $3,196,448  2024
#
# [304 rows x 3 columns]
# Empty DataFrame
# Columns: [Player, Salary, Year]
# Index: []

# %%
df
